# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('superstore_final_dataset.csv', index_col= "Row_ID")
df
# Out:
#               Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# Row_ID
# 1       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 3       CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 4       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...                ...         ...         ...             ...         ...
# 9796    CA-2017-125920  21/05/2017  28/05/2017  Standard Class    SH-19975
# 9797    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9798    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9799    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9800    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
# ...

# %% [markdown]
# •	Step 1: Removing duplicate rows

# %%
df[df.duplicated()]
# Out:
#               Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# Row_ID
# 3407    US-2015-150119  23/04/2015  27/04/2015  Standard Class    LB-16795
#
#          Customer_Name      Segment        Country      City State  \
# Row_ID
# 3407    Laurel Beltran  Home Office  United States  Columbus  Ohio
#
#         Postal_Code Region       Product_ID   Category Sub_Category  \
# Row_ID
# 3407        43229.0   East  FUR-CH-10002965  Furniture       Chairs
#
#                                              Product_Name    Sales
# Row_ID
# 3407    Global Leather Highback Executive Chair with P...  281.372

# %%
df.drop_duplicates(inplace= True)
df
# Out:
#               Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# Row_ID
# 1       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 3       CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 4       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...                ...         ...         ...             ...         ...
# 9796    CA-2017-125920  21/05/2017  28/05/2017  Standard Class    SH-19975
# 9797    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9798    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9799    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9800    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
# ...

# %% [markdown]
# •	Step 2: Removing rows for which few values are missing.

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Ship_Date         0
# Ship_Mode         0
# Customer_ID       0
# Customer_Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal_Code      11
# Region            0
# Product_ID        0
# Category          0
# Sub_Category      0
# Product_Name      0
# Sales             0
# dtype: int64

# %%
df.isnull()
# Out:
#         Order_ID  Order_Date  Ship_Date  Ship_Mode  Customer_ID  \
# Row_ID
# 1          False       False      False      False        False
# 2          False       False      False      False        False
# 3          False       False      False      False        False
# 4          False       False      False      False        False
# 5          False       False      False      False        False
# ...          ...         ...        ...        ...          ...
# 9796       False       False      False      False        False
# 9797       False       False      False      False        False
# 9798       False       False      False      False        False
# 9799       False       False      False      False        False
# 9800       False       False      False      False        False
#
#         Customer_Name  Segment  Country   City  State  Postal_Code  Region  \
# Row_ID
# 1               False    False    False  False  False        False   False
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#               Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# Row_ID
# 2235    CA-2018-104066  05/12/2018  10/12/2018  Standard Class    QJ-19255
# 5275    CA-2016-162887  07/11/2016  09/11/2016    Second Class    SV-20785
# 8799    US-2017-150140  06/04/2017  10/04/2017  Standard Class    VM-21685
# 9147    US-2017-165505  23/01/2017  27/01/2017  Standard Class    CB-12535
# 9148    US-2017-165505  23/01/2017  27/01/2017  Standard Class    CB-12535
# 9149    US-2017-165505  23/01/2017  27/01/2017  Standard Class    CB-12535
# 9387    US-2018-127292  19/01/2018  23/01/2018  Standard Class    RM-19375
# 9388    US-2018-127292  19/01/2018  23/01/2018  Standard Class    RM-19375
# 9389    US-2018-127292  19/01/2018  23/01/2018  Standard Class    RM-19375
# 9390    US-2018-127292  19/01/2018  23/01/2018  Standard Class    RM-19375
# 9742    CA-2016-117086  08/11/2016  12/11/2016  Standard Class    QJ-19255
#
# ...

# %%
df.dropna(inplace= True)
df
# Out:
#               Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# Row_ID
# 1       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 3       CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 4       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...                ...         ...         ...             ...         ...
# 9796    CA-2017-125920  21/05/2017  28/05/2017  Standard Class    SH-19975
# 9797    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9798    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9799    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9800    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
# ...

# %% [markdown]
# •	Step 3: Remove irrelevant values from each column if any.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9788 entries, 1 to 9800
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       9788 non-null   object
#  1   Order_Date     9788 non-null   object
#  2   Ship_Date      9788 non-null   object
#  3   Ship_Mode      9788 non-null   object
#  4   Customer_ID    9788 non-null   object
#  5   Customer_Name  9788 non-null   object
#  6   Segment        9788 non-null   object
#  7   Country        9788 non-null   object
#  8   City           9788 non-null   object
#  9   State          9788 non-null   object
#  10  Postal_Code    9788 non-null   float64
#  11  Region         9788 non-null   object
#  12  Product_ID     9788 non-null   object
#  13  Category       9788 non-null   object
#  14  Sub_Category   9788 non-null   object
#  15  Product_Name   9788 non-null   object
#  16  Sales          9788 non-null   float64
# ...

# %%
df['Postal_Code']= df['Postal_Code'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9788 entries, 1 to 9800
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       9788 non-null   object
#  1   Order_Date     9788 non-null   object
#  2   Ship_Date      9788 non-null   object
#  3   Ship_Mode      9788 non-null   object
#  4   Customer_ID    9788 non-null   object
#  5   Customer_Name  9788 non-null   object
#  6   Segment        9788 non-null   object
#  7   Country        9788 non-null   object
#  8   City           9788 non-null   object
#  9   State          9788 non-null   object
#  10  Postal_Code    9788 non-null   int32
#  11  Region         9788 non-null   object
#  12  Product_ID     9788 non-null   object
#  13  Category       9788 non-null   object
#  14  Sub_Category   9788 non-null   object
#  15  Product_Name   9788 non-null   object
#  16  Sales          9788 non-null   float64
# ...

# %%
df.describe(include='all').T
# Out:
#                 count unique              top  freq          mean  \
# Order_ID         9788   4916   CA-2018-100111    14           NaN
# Order_Date       9788   1229       05/09/2017    38           NaN
# Ship_Date        9788   1326       26/09/2018    34           NaN
# Ship_Mode        9788      4   Standard Class  5848           NaN
# Customer_ID      9788    793         WB-21850    35           NaN
# Customer_Name    9788    793    William Brown    35           NaN
# Segment          9788      3         Consumer  5096           NaN
# Country          9788      1    United States  9788           NaN
# City             9788    529    New York City   891           NaN
# State            9788     48       California  1946           NaN
# Postal_Code    9788.0    NaN              NaN   NaN  55274.552922
# Region           9788      4             West  3140           NaN
# Product_ID       9788   1860  OFF-PA-10001970    18           NaN
# ...

# %%
df.head()
# Out:
#               Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# Row_ID
# 1       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 3       CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 4       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#           Customer_Name    Segment        Country             City  \
# Row_ID
# 1           Claire Gute   Consumer  United States        Henderson
# 2           Claire Gute   Consumer  United States        Henderson
# 3       Darrin Van Huff  Corporate  United States      Los Angeles
# 4         Sean O Donnel   Consumer  United States  Fort Lauderdale
# 5         Sean O Donnel   Consumer  United States  Fort Lauderdale
#
#              State  Postal_Code Region       Product_ID         Category  \
# Row_ID
# ...

# %%
df['Ship_Date']= pd.to_datetime(df['Ship_Date'], format='%d/%m/%Y')

# %%
df.head()
# Out:
#               Order_ID  Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# Row_ID
# 1       CA-2017-152156  08/11/2017 2017-11-11    Second Class    CG-12520
# 2       CA-2017-152156  08/11/2017 2017-11-11    Second Class    CG-12520
# 3       CA-2017-138688  12/06/2017 2017-06-16    Second Class    DV-13045
# 4       US-2016-108966  11/10/2016 2016-10-18  Standard Class    SO-20335
# 5       US-2016-108966  11/10/2016 2016-10-18  Standard Class    SO-20335
#
#           Customer_Name    Segment        Country             City  \
# Row_ID
# 1           Claire Gute   Consumer  United States        Henderson
# 2           Claire Gute   Consumer  United States        Henderson
# 3       Darrin Van Huff  Corporate  United States      Los Angeles
# 4         Sean O Donnel   Consumer  United States  Fort Lauderdale
# 5         Sean O Donnel   Consumer  United States  Fort Lauderdale
#
#              State  Postal_Code Region       Product_ID         Category  \
# Row_ID
# ...

# %% [markdown]
# Validation of all values for a column (order date and ship date value must be in correct date format). For each entry in dataset ship date >= order date

# %%
df['Order_Date']= pd.to_datetime(df['Order_Date'], format='%d/%m/%Y')
df.head()
# Out:
#               Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# Row_ID
# 1       CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 3       CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 4       US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 5       US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#           Customer_Name    Segment        Country             City  \
# Row_ID
# 1           Claire Gute   Consumer  United States        Henderson
# 2           Claire Gute   Consumer  United States        Henderson
# 3       Darrin Van Huff  Corporate  United States      Los Angeles
# 4         Sean O Donnel   Consumer  United States  Fort Lauderdale
# 5         Sean O Donnel   Consumer  United States  Fort Lauderdale
#
#              State  Postal_Code Region       Product_ID         Category  \
# Row_ID
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9788 entries, 1 to 9800
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       9788 non-null   object
#  1   Order_Date     9788 non-null   datetime64[ns]
#  2   Ship_Date      9788 non-null   datetime64[ns]
#  3   Ship_Mode      9788 non-null   object
#  4   Customer_ID    9788 non-null   object
#  5   Customer_Name  9788 non-null   object
#  6   Segment        9788 non-null   object
#  7   Country        9788 non-null   object
#  8   City           9788 non-null   object
#  9   State          9788 non-null   object
#  10  Postal_Code    9788 non-null   int32
#  11  Region         9788 non-null   object
#  12  Product_ID     9788 non-null   object
#  13  Category       9788 non-null   object
#  14  Sub_Category   9788 non-null   object
#  15  Product_Name   9788 non-null   object
#  16  Sales          9788 non-null   float64
# ...

# %%
df[df['Ship_Date']< df['Order_Date']]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Ship_Date, Ship_Mode, Customer_ID, Customer_Name, Segment, Country, City, State, Postal_Code, Region, Product_ID, Category, Sub_Category, Product_Name, Sales]
# Index: []

# %% [markdown]
# This shows that there are no values where ship_date is before order date.

# %% [markdown]
# •	Step 4: Export the cleaned dataset as a .csv file: prefer UTF-8 encoding.

# %%
df.to_csv('superstore_cleaned_dataset.csv',encoding= 'utf-8' )
